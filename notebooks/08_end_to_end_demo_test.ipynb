# %% [markdown]
# # 08 - End-to-End Demo Test
#
# ## Stage 9 Objective
#
# Run a small end-to-end workflow before wiring the Streamlit demo.
#
# ## Notes
#
# - Use sample clauses and saved lightweight models when available.
# - Verify simplification, classification, and Q&A outputs together.
# - Confirm the app includes the educational-use legal disclaimer.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
APP_PATH = PROJECT_ROOT / 'app.py'

print(f'App path: {APP_PATH}')
print(f'App file exists: {APP_PATH.exists()}')
